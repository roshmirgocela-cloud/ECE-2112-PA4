# %% [markdown]
# # **EXPERIMENT 4:  DATA WRANGLING AND DATA VISUALIZATION**
# >## Name: Roshmir Janylin C. Gocela
# >### SECTION: 2ECE-B
# >### DATE SUBMITTED: September 17, 2026

# %% [markdown]
# ---

# %% [markdown]
# #### To access the Pandas library, the Matplotlib library, and the board2.xlsx file

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel('board2.xlsx')
df ['Average'] = (df.Math + df.Electronics + df.GEAS + df.Communication)/4
print("\nUPLOADED DATAFRAME FROM EXCEL FILE: ")
display (df)
# Out:
# UPLOADED DATAFRAME FROM EXCEL FILE:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# 13  S14  Female  Microelectronics     Luzon    83           77    89
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 15  S16  Female     Communication     Luzon    71           70    87
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 17  S18    Male     Communication   Visayas    81           40    81
# 18  S19    Male  Microelectronics     Luzon    79           63    79
# 19  S20  Female     Communication  Mindanao    59           60    62
# 20  S21  Female  Microelectronics   Visayas    83           51    68
# 21  S22  Female     Communication   Visayas    64           39    89
# 22  S23    Male   Instrumentation     Luzon    84           70    74
# 23  S24  Female  Microelectronics   Visayas    85           45    60
# 24  S25    Male     Communication     Luzon    74           91    94
# 25  S26  Female   Instrumentation   Visayas    71           47    83
# 26  S27    Male  Microelectronics   Visayas    70           47    40
# 27  S28    Male     Communication   Visayas    85           53    80
# 28  S29    Male   Instrumentation  Mindanao    73           48    71
# 29  S30    Male   Instrumentation     Luzon    78           81    57
#
#     Communication  Average
# 0              78    75.00
# 1              52    67.25
# 2              57    72.75
# 3              68    70.50
# 4              88    69.00
# 5              83    75.50
# 6              48    58.50
# 7              53    61.75
# 8              42    47.75
# 9              44    67.25
# 10             67    54.75
# 11             64    76.00
# 12             43    62.25
# 13             73    80.50
# 14             86    59.00
# 15             81    77.25
# 16             45    70.50
# 17             52    63.50
# 18             71    73.00
# 19             85    66.50
# 20             72    68.50
# 21             58    62.50
# 22             47    68.75
# 23             41    57.75
# 24             42    75.25
# 25             62    65.75
# 26             86    60.75
# 27             53    67.75
# 28             62    63.50
# 29             56    68.00

# %% [markdown]
# # PROGRAMMING PROBLEMS FOR EXPERIMENT 4:

# %% [markdown]
# ## A. VISAYAS COMMUNICATION DATAFRAME

# %%
VisComm = df[(df['Hometown'] == 'Visayas') &
             (df['Track'] == 'Communication')
             ][['Name', 'Gender', 'Math', 'Electronics', 'Average']]

display (VisComm)

print ("Number of rows:", len (VisComm))
# Out:
#    Name  Gender  Math  Electronics  Average
# 10  S11  Female    48           56    54.75
# 11  S12    Male    89           67    76.00
# 17  S18    Male    81           40    63.50
# 21  S22  Female    64           39    62.50
# 27  S28    Male    85           53    67.75
# Number of rows: 5

# %% [markdown]
# ##

# %% [markdown]
# ## B. VISAYAS FEMALE DATAFRAME

# %%
VisFemale = df[(df['Hometown']=='Visayas') & (df['Gender'] == 'Female')][['Name', 'Track', 'GEAS', 'Electronics', 'Average']]
display (VisFemale)

print ("\nFemale Students in Visayas whose average in GEAS and Electronics is atleast 60")
display (VisFemale[VisFemale['Average']>=60])
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 10  S11     Communication    48           56    54.75
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 23  S24  Microelectronics    60           45    57.75
# 25  S26   Instrumentation    83           47    65.75
# Female Students in Visayas whose average in GEAS and Electronics is atleast 60
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 25  S26   Instrumentation    83           47    65.75

# %% [markdown]
# ##

# %% [markdown]
# ## C.  CATEGORY-AVERAGE VISUALIZATION

# %% [markdown]
# ##### a. For each feature, compute the mean of Average for every category using Pandas

# %%
mean_track = df.groupby('Track')['Average'].mean().reset_index()
mean_gender = df.groupby('Gender')['Average'].mean().reset_index()
mean_hometown = df.groupby('Hometown')['Average'].mean().reset_index()

print("\nMean Average by Track")
display(mean_track)

print("\nMean Average by Gender")
display(mean_gender)

print("\nMean Average by Hometown")
display(mean_hometown)
# Out:
# Mean Average by Track
#               Track  Average
# 0     Communication   67.975
# 1   Instrumentation   65.225
# 2  Microelectronics   67.500
# Mean Average by Gender
#    Gender    Average
# 0  Female  66.616667
# 1    Male  67.183333
# Mean Average by Hometown
#    Hometown    Average
# 0     Luzon  68.083333
# 1  Mindanao  66.678571
# 2   Visayas  65.750000

# %% [markdown]
# ####

# %% [markdown]
# ##### b. Display the three summary tables.

# %%
display(pd.concat([Mean_Track, Mean_Gender, Mean_Hometown], 
                  keys=['Track', 'Gender', 'Hometown']))
# Out:
#                              Average
# Track    Communication     67.975000
#          Instrumentation   65.225000
#          Microelectronics  67.500000
# Gender   Female            66.616667
#          Male              67.183333
# Hometown Luzon             68.083333
#          Mindanao          66.678571
#          Visayas           65.750000

# %% [markdown]
# ####

# %% [markdown]
# ##### c. Create one figure containing three bar charts: mean Average by Track, by Gender, and by Hometown.

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)
fig.suptitle('Mean Average by Track, Gender, and Hometown', fontsize=16, fontweight='bold')

axes[0].bar(mean_track['Track'], mean_track['Average'], color='#8dd3c7')
axes[0].set_title('Mean Average by Track')
axes[0].set_xlabel('Track')
axes[0].set_ylabel('Mean Average Score')
axes[0].set_ylim(0, 100)

axes[1].bar(mean_gender['Gender'], mean_gender['Average'], color='#ffffb3')
axes[1].set_title('Mean Average by Gender')
axes[1].set_xlabel('Gender')
axes[1].set_ylabel('Mean Average Score')

axes[2].bar(mean_hometown['Hometown'], mean_hometown['Average'], color='#b4aee0')
axes[2].set_title('Mean Average by Hometown')
axes[2].set_xlabel('Hometown')
axes[2].set_ylabel('Mean Average Score')

plt.tight_layout()
plt.show()

highest_track = mean_track.loc[mean_track['Average'].idxmax(), 'Track']
highest_gender = mean_gender.loc[mean_gender['Average'].idxmax(), 'Gender']
highest_hometown = mean_hometown.loc[mean_hometown['Average'].idxmax(), 'Hometown']

# %% [markdown]
# ####

# %% [markdown]
# ##### d. Below the figure, write three concise statements identifying the category with the highest sample mean for each feature.

# %%
T = round(float(Mean_Track['Average'].max()), 3)
MT = Mean_Track['Average'].idxmax()

G = round(float(Mean_Gender['Average'].max()), 3)
MG = Mean_Gender['Average'].idxmax()

H = round(float(Mean_Hometown['Average'].max()), 3)
MH = Mean_Hometown['Average'].idxmax()

print("\nThe Category with the Highest Sample Mean:\n")
print("  1. The Track feature has the highest sample mean is in the category", MT, "with an average of", T)
print("  2. The Gender feature has the highest sample mean is in the category", MG, "with an average of", G)
print("  3. The Hometown feature has the highest sample mean is in the category", MH, "with an average of", H)
# Out:
# The Category with the Highest Sample Mean:
#
#   1. The Track feature has the highest sample mean is in the category Communication with an average of 67.975
#   2. The Gender feature has the highest sample mean is in the category Male with an average of 67.183
#   3. The Hometown feature has the highest sample mean is in the category Luzon with an average of 68.083
